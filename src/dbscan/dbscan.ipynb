# %% [markdown]
# #### Relação de left_iris_x com screen_y

# %%
import dbscan_lib as dbs

# left_iris_x,left_iris_y,right_iris_x,right_iris_y,screen_x,screen_y
result = dbs.dbscanAlgo(x_df="left_iris_x", y_df="screen_y")
result.run()

# %% [markdown]
# #### Relação de screen_x com left_iris_y

# %%
# left_iris_x,left_iris_y,right_iris_x,right_iris_y,screen_x,screen_y
result = dbs.dbscanAlgo(x_df="screen_x", y_df="left_iris_y")
result.run()

# %% [markdown]
# #### Relação de right_iris_x com screen_y

# %%
result = dbs.dbscanAlgo(x_df="right_iris_x", y_df="screen_y")
result.run()

# %% [markdown]
# #### Relação de screen_x com right_iris_y

# %%
result = dbs.dbscanAlgo(x_df="screen_x", y_df="right_iris_y")
result.run()
